# %% [markdown]
# <h1>My Jupyter Notebook on IBM Data Science Experience</h1>

# %% [markdown]
# APARNA YADAV
#
#
# OCCUPATION-Student

# %% [markdown]
# <I>I am interested in data science because I love to play with data.It is very interesting thing to find insights from the data and create story out of them.
#
# Basically  data science is the field which helps us to find which things of our product needs improvement  to increase the sale in future.

# %% [markdown]
# <h3>Creating a dictionary of animals in zoo and how many people visited </h3>

# %%
# list={'lion':12,'rat':10,'monkey':10,'peacock':20}
s=list;
print(s);
# Out:
# {'lion': 12, 'rat': 10, 'monkey': 10, 'peacock': 20}

# %% [markdown]
# <q>Make your carrier in data science</q>
# <h2>Books Of Data Science</h2>
#  <img src="https://www.analyticsvidhya.com/wp-content/uploads/2016/10/8314929977_28fd740070_b.jpg"   height=100 width=100/>
# <center><h2><u>Books on Statistics</u></h2></center>
# <li>Statistics in Plain English by   "Timothy C. Urdan"</li>
# <li>Think Stats: Probability and Statistics for Programmers by    "Allen B. Downey"</li>
# <li>Introduction to Statistical Learning by   "Gareth James, Daniela Witten, Trevor Hastie and Robert Tibshirani"</li>
# </ol>
# <ol>
# <center><h2><u>Books on  Probability</u></h2></center>
# <li>Probability: For the Enthusiastic Beginner by  "David Morin" </li>
# <li>Introduction to Probability by   "J. Laurie Snell and Charles Miller Grinstead"</li>
# <li>An Introduction to Probability Theory and its Applications by   "William Feller "</li>
# </ol></center>
# <h2>Links for books of data science</h2>
# <ol><li><a style="font-size:20px" alink="blue" vlink="purple" href="http://flowingdata.com">flowingdata.com</a>
# </li>
# <li>
# <a style="font-size:20px" alink="blue" vlink="purple" href="http://www.analyticsvidhya.com">www.analytics.com</a></li></ol>
#
# <hr>
# <h2>Fastest Growing stem undergraduate degree 2010-2013</h2>
# <table><tr>
#     <td>field</td>
#     <td>% increase from 2010</td>
#     <td># of 2013 degree</td></tr><tr>
#     <td>Statitics</td>
#     <td>95.1</td>
#     <td>1,656</td></tr>
#     <tr>
#         <td>Computer Programming</td>
#         <td>77.2</td>
#         <td>466</td>
#     </tr>
# </table>
